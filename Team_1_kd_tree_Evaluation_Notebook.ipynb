# %% [markdown]
# # This Notebook for Running the ADB Project Phase 2

# %% [markdown]
# **This notebook is divided into two main parts, each focusing on different database sizes:**
# - **Part 1: Database Size 10K**
#   - Initiate a new database and insert vectors into it.
#   - Retrieve vectors from the database.
#   - Ensure that the insertion time for this database does not exceed 5 minutes.
#   - Allow flexible RAM usage during insertion but ensure it stays within Google Colab limits.
#   - Evaluate retrieval time and accuracy.
#   - Ensure that the peak RAM usage for retrieval does not exceed 5 MB.
#
# - **Part 2: Database Sizes 100K and More**
#   - Generate database vectors using a random seed (refer to the provided code).
#   - You have generate the database and its index before the submission.
#   - Implement a VecDB class that loads the pre-generated database, including the index, and retrieves vectors, to load the generated database.
#   - Evaluate retrieval time and accuracy for different database sizes.
#   - The Peak RAM usage for the retrieval should not exceed
#     - For 100 K --> 10 MB
#     - For 1 M --> 25 MB
#     - For 5 M --> 75 MB
#     - For 10 M --> 150 MB
#     - For 15 M --> 225 MB
#     - For 20 M --> 300 MB
#
# **This notebook is structured into two parts:**
#
# - **Part 1 - Modifiable Cells:**
# This section contains cells that teams are allowed to modify. The modification are only variables and to be submitted during the project's final phase. They are
#   - GitHub repository link (including PAT token).
#   - Database (DB) variables, providing the path to the directory or file for loading existing databases and indexes (refer to provided code to see how).
#
# - **Part 2 - Non-Modifiable Cells:** This section must not be modified by any team. It includes essential setup and evaluation code. Ensure that the notebook runs smoothly by providing the required inputs in Part 1.

# %% [markdown]
# ## Part 1 - Modifiable Cells

# %% [markdown]
# Of course each team will provide different github repo link
# Should include PAT token to enable me to download

# %%
# !git clone https://mtheggi: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@github.com/mtheggi/sematic_search_DB.git
# Out:
# Cloning into 'sematic_search_DB'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 56 (delta 25), reused 37 (delta 11), pack-reused 0
# Receiving objects: 100% (56/56), 30.41 KiB | 5.07 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %% [markdown]
# Teams are required to provide unique paths for the generated databases of sizes 1M, 5M, 10M, 15M, and 20M. Follow these steps to submit the databases:
#
# - Once you have the database and index ready, zip the necessary folders/files.
# - Upload the zip file to Google Drive.
# - Ensure the file is shareable with "anyone with the link."
# - Obtain the zip file link (e.g., https://drive.google.com/file/d/1j1gAU3kvdRqcOoKI5K5FgMMUZpOQANah/view?usp=drive_link).
# - Extract the zip file ID (e.g., 1j1gAU3kvdRqcOoKI5K5FgMMUZpOQANah).
# - Place the ID in the designated variable (to be submitted during the project final phase).
# - The code will automatically download the zip file and unzip it inside this directory.
# - Provide the local PATH for each database to be passed to the initializer for automatic loading of the database and index (to be submitted during the project final phase).

# %%
TEAM_NUMBER = 1
GDRIVE_ID_DB_100K = "1GFncvb9ghfQyjTxEnt2of2qC6l0xaXKr" # my 100k*
GDRIVE_ID_DB_1M = "1TXaOgR14U5wAywHO0lqMYkTP0R0XDpdr" # my 1m *
GDRIVE_ID_DB_5M = "1MLY5q2He6ddNpV4zTiBjct5erK3FZCl-" # my 5m *
GDRIVE_ID_DB_10M = "1yy4WJUN_Fb6bUq5uBFEFIodCaaGKWqhL"# my 10m *
GDRIVE_ID_DB_15M = "1U3uTVURkZBICS29bLuvOFs6fZ0U9SVU_" #my 15m *
GDRIVE_ID_DB_20M = "1j1gAU3kvdRqcOoKI5K5FgMMUZpOQANah"
PATH_DB_100K = "test_100k_d/output.csv"
PATH_DB_1M = "test_1m_d/output.csv"
PATH_DB_5M = "test_5m_d/output.csv"
PATH_DB_10M = "test_10m_d/output.csv"
PATH_DB_15M = "test_15m_d/output.csv"
PATH_DB_20M = "test_15m_d/output.csv"

# %% [markdown]
# These two varaible I'll change while running in on the discussion

# %%
QUERY_SEED_NUMBER = 10
DB_SEED_NUMBER = 20

# %% [markdown]
# This means that the project submission will include these
# - TEAM_NUMBER
# - Github clone link
# - GDRIVE_ID_DB_100K
# - GDRIVE_ID_DB_1M
# - GDRIVE_ID_DB_5M
# - GDRIVE_ID_DB_10M
# - GDRIVE_ID_DB_15M
# - GDRIVE_ID_DB_20M
# - PATH_DB_100K
# - PATH_DB_1M
# - PATH_DB_5M
# - PATH_DB_10M
# - PATH_DB_15M
# - PATH_DB_20M <br>
# - And for sure the project document that describes what you did

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ## Part 2: No edits from here
# #### You can't edit this part, and neither me.
# #### Note: Maybe I can edit if there is a major bug

# %%
# %cd sematic_search_DB
# Out:
# /content/sematic_search_DB

# %% [markdown]
# This cell to run any additional requirement that your code need <br>

# %%
# !pip install memory-profiler >> log.txt
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 1)) (1.23.5)
# Collecting csvsort==1.6.1 (from -r requirements.txt (line 2))
#   Downloading csvsort-1.6.1.tar.gz (3.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: csvsort
#   Building wheel for csvsort (setup.py) ... done
#   Created wheel for csvsort: filename=csvsort-1.6.1-py3-none-any.whl size=4091 sha256=c79edfbe63aef7f1e017244ecfa716b1d6a084f3d25b3238ea146525eac01038
#   Stored in directory: /root/.cache/pip/wheels/b9/ef/be/26ac1963436fdf9a7e477ffa63182d8010e7391b3001ee1aa7
# Successfully built csvsort
# Installing collected packages: csvsort
# Successfully installed csvsort-1.6.1

# %% [markdown]
# This cell to download the zip files and unzip them here.

# %%
# !gdown $GDRIVE_ID_DB_100K -O saved_db_100k.zip
# !gdown $GDRIVE_ID_DB_1M -O saved_db_1m.zip
# !gdown $GDRIVE_ID_DB_5M -O saved_db_5m.zip
# !gdown $GDRIVE_ID_DB_10M -O saved_db_10m.zip
# !gdown $GDRIVE_ID_DB_15M -O saved_db_15m.zip
# !gdown $GDRIVE_ID_DB_20M -O saved_db_20m.zip
# !unzip saved_db_100k.zip
# !unzip saved_db_1m.zip
# !unzip saved_db_5m.zip
# !unzip saved_db_10m.zip
# !unzip saved_db_15m.zip
# !unzip saved_db_20m.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GFncvb9ghfQyjTxEnt2of2qC6l0xaXKr
# To: /content/sematic_search_DB/saved_db_100k.zip
# 100% 32.3M/32.3M [00:00<00:00, 66.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TXaOgR14U5wAywHO0lqMYkTP0R0XDpdr
# To: /content/sematic_search_DB/saved_db_1m.zip
# 100% 323M/323M [00:05<00:00, 64.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MLY5q2He6ddNpV4zTiBjct5erK3FZCl-
# To: /content/sematic_search_DB/saved_db_5m.zip
# 100% 1.62G/1.62G [00:14<00:00, 108MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1yy4WJUN_Fb6bUq5uBFEFIodCaaGKWqhL
# To: /content/sematic_search_DB/saved_db_10m.zip
# 100% 3.24G/3.24G [00:32<00:00, 99.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1U3uTVURkZBICS29bLuvOFs6fZ0U9SVU_
# To: /content/sematic_search_DB/saved_db_15m.zip
# 100% 4.87G/4.87G [00:35<00:00, 138MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1j1gAU3kvdRqcOoKI5K5FgMMUZpOQANah
# To: /content/sematic_search_DB/saved_db_20m.zip
# 100% 28.5M/28.5M [00:00<00:00, 64.0MB/s]
# Archive:  saved_db_100k.zip
#    creating: test_100k_d/
#   inflating: test_100k_d/Cluster0.csv
#   inflating: test_100k_d/Cluster1.csv
#   inflating: test_100k_d/Cluster2.csv
#   inflating: test_100k_d/Cluster3.csv
#   inflating: test_100k_d/output.csv
#   inflating: test_100k_d/Cluster4.csv
#   inflating: test_100k_d/Cluster5.csv
#   inflating: test_100k_d/Cluster6.csv
#   inflating: test_100k_d/Cluster7.csv
#   inflating: test_100k_d/Cluster8.csv
#   inflating: test_100k_d/Cluster9.csv
#   inflating: test_100k_d/Cluster10.csv
#   inflating: test_100k_d/Cluster11.csv
#   inflating: test_100k_d/Cluster12.csv
#   inflating: test_100k_d/Cluster13.csv
#   inflating: test_100k_d/Cluster14.csv
#   inflating: test_100k_d/Cluster15.csv
# Archive:  saved_db_1m.zip
#    creating: test_1m_d/
#   inflating: test_1m_d/Cluster76.csv
#   inflating: test_1m_d/Cluster52.csv
#   inflating: test_1m_d/Cluster59.csv
#   inflating: test_1m_d/Cluster1.csv
#   inflating: test_1m_d/Cluster92.csv
#   inflating: test_1m_d/Cluster38.csv
#   inflating: test_1m_d/Cluster8.csv
#   inflating: test_1m_d/Cluster68.csv
#   inflating: test_1m_d/Cluster55.csv
#   inflating: test_1m_d/Cluster45.csv
#   inflating: test_1m_d/Cluster42.csv
#   inflating: test_1m_d/Cluster56.csv
#   inflating: test_1m_d/Cluster5.csv
#   inflating: test_1m_d/Cluster82.csv
#   inflating: test_1m_d/Cluster89.csv
#   inflating: test_1m_d/Cluster100.csv
#   inflating: test_1m_d/Cluster71.csv
#   inflating: test_1m_d/Cluster103.csv
#   inflating: test_1m_d/Cluster37.csv
#   inflating: test_1m_d/Cluster77.csv
#   inflating: test_1m_d/Cluster101.csv
#   inflating: test_1m_d/Cluster19.csv
#   inflating: test_1m_d/Cluster88.csv
#   inflating: test_1m_d/Cluster64.csv
#   inflating: test_1m_d/Cluster13.csv
#   inflating: test_1m_d/Cluster36.csv
#   inflating: test_1m_d/Cluster30.csv
#   inflating: test_1m_d/Cluster107.csv
#   inflating: test_1m_d/Cluster81.csv
#   inflating: test_1m_d/Cluster60.csv
#   inflating: test_1m_d/Cluster110.csv
#   inflating: test_1m_d/Cluster123.csv
#   inflating: test_1m_d/Cluster108.csv
#   inflating: test_1m_d/Cluster87.csv
#   inflating: test_1m_d/Cluster11.csv
#   inflating: test_1m_d/Cluster34.csv
#   inflating: test_1m_d/Cluster33.csv
#   inflating: test_1m_d/Cluster21.csv
#   inflating: test_1m_d/Cluster126.csv
#   inflating: test_1m_d/Cluster47.csv
#   inflating: test_1m_d/Cluster114.csv
#   inflating: test_1m_d/output.csv
#   inflating: test_1m_d/Cluster109.csv
#   inflating: test_1m_d/Cluster90.csv
#   inflating: test_1m_d/Cluster75.csv
#   inflating: test_1m_d/Cluster122.csv
#   inflating: test_1m_d/Cluster29.csv
#   inflating: test_1m_d/Cluster57.csv
#   inflating: test_1m_d/Cluster112.csv
#   inflating: test_1m_d/Cluster17.csv
#   inflating: test_1m_d/Cluster28.csv
#   inflating: test_1m_d/Cluster14.csv
#   inflating: test_1m_d/Cluster72.csv
#   inflating: test_1m_d/Cluster15.csv
#   inflating: test_1m_d/Cluster93.csv
#   inflating: test_1m_d/Cluster22.csv
#   inflating: test_1m_d/Cluster24.csv
#   inflating: test_1m_d/Cluster58.csv
#   inflating: test_1m_d/Cluster44.csv
#   inflating: test_1m_d/Cluster49.csv
#   inflating: test_1m_d/Cluster62.csv
#   inflating: test_1m_d/Cluster106.csv
#   inflating: test_1m_d/Cluster94.csv
#   inflating: test_1m_d/Cluster98.csv
#   inflating: test_1m_d/Cluster27.csv
#   inflating: test_1m_d/Cluster51.csv
#   inflating: test_1m_d/Cluster20.csv
#   inflating: test_1m_d/Cluster79.csv
#   inflating: test_1m_d/Cluster25.csv
#   inflating: test_1m_d/Cluster16.csv
#   inflating: test_1m_d/Cluster12.csv
#   inflating: test_1m_d/Cluster97.csv
#   inflating: test_1m_d/Cluster83.csv
#   inflating: test_1m_d/Cluster26.csv
#   inflating: test_1m_d/Cluster32.csv
#   inflating: test_1m_d/Cluster4.csv
#   inflating: test_1m_d/Cluster73.csv
#   inflating: test_1m_d/Cluster117.csv
#   inflating: test_1m_d/Cluster10.csv
#   inflating: test_1m_d/Cluster23.csv
#   inflating: test_1m_d/Cluster18.csv
#   inflating: test_1m_d/Cluster9.csv
#   inflating: test_1m_d/Cluster69.csv
#   inflating: test_1m_d/Cluster53.csv
#   inflating: test_1m_d/Cluster46.csv
#   inflating: test_1m_d/Cluster7.csv
#   inflating: test_1m_d/Cluster104.csv
#   inflating: test_1m_d/Cluster102.csv
#   inflating: test_1m_d/Cluster84.csv
#   inflating: test_1m_d/Cluster95.csv
#   inflating: test_1m_d/Cluster121.csv
#   inflating: test_1m_d/Cluster86.csv
#   inflating: test_1m_d/Cluster105.csv
#   inflating: test_1m_d/Cluster2.csv
#   inflating: test_1m_d/Cluster65.csv
#   inflating: test_1m_d/Cluster39.csv
#   inflating: test_1m_d/Cluster70.csv
#   inflating: test_1m_d/Cluster66.csv
#   inflating: test_1m_d/Cluster113.csv
#   inflating: test_1m_d/Cluster120.csv
#   inflating: test_1m_d/Cluster6.csv
#   inflating: test_1m_d/Cluster31.csv
#   inflating: test_1m_d/Cluster127.csv
#   inflating: test_1m_d/Cluster43.csv
#   inflating: test_10m_d/Cluster213.csv
#   inflating: test_10m_d/Cluster651.csv
#   inflating: test_10m_d/Cluster622.csv
#   inflating: test_10m_d/Cluster420.csv
#   inflating: test_10m_d/Cluster59.csv
#   inflating: test_10m_d/Cluster1.csv
#   inflating: test_10m_d/Cluster344.csv
#   inflating: test_10m_d/Cluster247.csv
#   inflating: test_10m_d/Cluster92.csv
#   inflating: test_10m_d/Cluster364.csv
#   inflating: test_10m_d/Cluster973.csv
#   inflating: test_10m_d/Cluster503.csv
#   inflating: test_10m_d/Cluster215.csv
#   inflating: test_10m_d/Cluster434.csv
#   inflating: test_10m_d/Cluster804.csv
#   inflating: test_10m_d/Cluster843.csv
#   inflating: test_10m_d/Cluster909.csv
#   inflating: test_10m_d/Cluster38.csv
#   inflating: test_10m_d/Cluster1006.csv
#   inflating: test_10m_d/Cluster419.csv
#   inflating: test_10m_d/Cluster806.csv
#   inflating: test_10m_d/Cluster610.csv
#   inflating: test_10m_d/Cluster748.csv
#   inflating: test_10m_d/Cluster180.csv
#   inflating: test_10m_d/Cluster231.csv
#   inflating: test_10m_d/Cluster156.csv
#   inflating: test_10m_d/Cluster218.csv
#   inflating: test_10m_d/Cluster8.csv
#   inflating: test_10m_d/Cluster636.csv
#   inflating: test_10m_d/Cluster632.csv
#   inflating: test_10m_d/Cluster68.csv
#   inflating: test_10m_d/Cluster55.csv
#   inflating: test_10m_d/Cluster739.csv
#   inflating: test_10m_d/Cluster45.csv
#   inflating: test_10m_d/Cluster567.csv
#   inflating: test_10m_d/Cluster660.csv
#   inflating: test_10m_d/Cluster42.csv
#   inflating: test_10m_d/Cluster159.csv
#   inflating: test_10m_d/Cluster56.csv
#   inflating: test_10m_d/Cluster495.csv
#   inflating: test_10m_d/Cluster181.csv
#   inflating: test_10m_d/Cluster425.csv
#   inflating: test_10m_d/Cluster949.csv
#   inflating: test_10m_d/Cluster281.csv
#   inflating: test_10m_d/Cluster650.csv
#   inflating: test_10m_d/Cluster575.csv
#   inflating: test_10m_d/Cluster130.csv
#   inflating: test_10m_d/Cluster592.csv
#   inflating: test_10m_d/Cluster767.csv
#   inflating: test_10m_d/Cluster535.csv
#   inflating: test_10m_d/Cluster317.csv
#   inflating: test_10m_d/Cluster376.csv
#   inflating: test_10m_d/Cluster5.csv
#   inflating: test_10m_d/Cluster129.csv
#   inflating: test_10m_d/Cluster255.csv
#   inflating: test_10m_d/Cluster873.csv
#   inflating: test_10m_d/Cluster846.csv
#   inflating: test_10m_d/Cluster196.csv
#   inflating: test_10m_d/Cluster983.csv
#   inflating: test_10m_d/Cluster82.csv
#   inflating: test_10m_d/Cluster89.csv
#   inflating: test_10m_d/Cluster799.csv
#   inflating: test_10m_d/Cluster331.csv
#   inflating: test_10m_d/Cluster911.csv
#   inflating: test_10m_d/Cluster996.csv
#   inflating: test_10m_d/Cluster900.csv
#   inflating: test_10m_d/Cluster904.csv
#   inflating: test_10m_d/Cluster100.csv
#   inflating: test_10m_d/Cluster340.csv
#   inflating: test_10m_d/Cluster71.csv
#   inflating: test_10m_d/Cluster565.csv
#   inflating: test_10m_d/Cluster989.csv
#   inflating: test_10m_d/Cluster952.csv
#   inflating: test_10m_d/Cluster563.csv
#   inflating: test_10m_d/Cluster103.csv
#   inflating: test_10m_d/Cluster924.csv
#   inflating: test_10m_d/Cluster37.csv
#   inflating: test_10m_d/Cluster870.csv
#   inflating: test_10m_d/Cluster267.csv
#   inflating: test_10m_d/Cluster268.csv
#   inflating: test_10m_d/Cluster435.csv
#   inflating: test_10m_d/Cluster901.csv
#   inflating: test_10m_d/Cluster488.csv
#   inflating: test_10m_d/Cluster249.csv
#   inflating: test_10m_d/Cluster77.csv
#   inflating: test_10m_d/Cluster152.csv
#   inflating: test_10m_d/Cluster439.csv
#   inflating: test_10m_d/Cluster101.csv
#   inflating: test_10m_d/Cluster961.csv
#   inflating: test_10m_d/Cluster202.csv
#   inflating: test_10m_d/Cluster449.csv
#   inflating: test_10m_d/Cluster290.csv
#   inflating: test_10m_d/Cluster185.csv
#   inflating: test_10m_d/Cluster789.csv
#   inflating: test_10m_d/Cluster492.csv
#   inflating: test_10m_d/Cluster246.csv
#   inflating: test_10m_d/Cluster167.csv
#   inflating: test_10m_d/Cluster441.csv
#   inflating: test_10m_d/Cluster601.csv
#   inflating: test_10m_d/Cluster975.csv
#   inflating: test_10m_d/Cluster882.csv
#   inflating: test_10m_d/Cluster155.csv
#   inflating: test_10m_d/Cluster704.csv
#   inflating: test_10m_d/Cluster845.csv
#   inflating: test_10m_d/Cluster19.csv
#   inflating: test_10m_d/Cluster464.csv
#   inflating: test_10m_d/Cluster805.csv
#   inflating: test_10m_d/Cluster791.csv
#   inflating: test_10m_d/Cluster221.csv
#   inflating: test_10m_d/Cluster88.csv
#   inflating: test_10m_d/Cluster560.csv
#   inflating: test_10m_d/Cluster899.csv
#   inflating: test_10m_d/Cluster147.csv
#   inflating: test_10m_d/Cluster639.csv
#   inflating: test_10m_d/Cluster373.csv
#   inflating: test_10m_d/Cluster817.csv
#   inflating: test_10m_d/Cluster359.csv
#   inflating: test_10m_d/Cluster679.csv
#   inflating: test_10m_d/Cluster64.csv
#   inflating: test_10m_d/Cluster529.csv
#   inflating: test_10m_d/Cluster745.csv
#   inflating: test_10m_d/Cluster744.csv
#   inflating: test_10m_d/Cluster908.csv
#   inflating: test_10m_d/Cluster333.csv
#   inflating: test_10m_d/Cluster795.csv
#   inflating: test_10m_d/Cluster531.csv
#   inflating: test_10m_d/Cluster13.csv
#   inflating: test_10m_d/Cluster308.csv
#   inflating: test_10m_d/Cluster36.csv
#   inflating: test_10m_d/Cluster396.csv
#   inflating: test_10m_d/Cluster358.csv
#   inflating: test_10m_d/Cluster984.csv
#   inflating: test_10m_d/Cluster1019.csv
#   inflating: test_10m_d/Cluster594.csv
#   inflating: test_10m_d/Cluster681.csv
#   inflating: test_10m_d/Cluster225.csv
#   inflating: test_10m_d/Cluster787.csv
#   inflating: test_10m_d/Cluster596.csv
#   inflating: test_10m_d/Cluster30.csv
#   inflating: test_10m_d/Cluster204.csv
#   inflating: test_10m_d/Cluster356.csv
#   inflating: test_10m_d/Cluster801.csv
#   inflating: test_10m_d/Cluster107.csv
#   inflating: test_10m_d/Cluster765.csv
#   inflating: test_10m_d/Cluster689.csv
#   inflating: test_10m_d/Cluster470.csv
#   inflating: test_10m_d/Cluster348.csv
#   inflating: test_10m_d/Cluster277.csv
#   inflating: test_10m_d/Cluster240.csv
#   inflating: test_10m_d/Cluster597.csv
#   inflating: test_10m_d/Cluster81.csv
#   inflating: test_10m_d/Cluster609.csv
#   inflating: test_10m_d/Cluster546.csv
#   inflating: test_10m_d/Cluster854.csv
#   inflating: test_10m_d/Cluster907.csv
#   inflating: test_10m_d/Cluster976.csv
#   inflating: test_10m_d/Cluster190.csv
#   inflating: test_10m_d/Cluster504.csv
#   inflating: test_10m_d/Cluster501.csv
#   inflating: test_10m_d/Cluster550.csv
#   inflating: test_10m_d/Cluster703.csv
#   inflating: test_10m_d/Cluster797.csv
#   inflating: test_10m_d/Cluster477.csv
#   inflating: test_10m_d/Cluster928.csv
#   inflating: test_10m_d/Cluster926.csv
#   inflating: test_10m_d/Cluster852.csv
#   inflating: test_10m_d/Cluster200.csv
#   inflating: test_10m_d/Cluster60.csv
#   inflating: test_10m_d/Cluster802.csv
#   inflating: test_10m_d/Cluster137.csv
#   inflating: test_10m_d/Cluster599.csv
#   inflating: test_10m_d/Cluster224.csv
#   inflating: test_10m_d/Cluster670.csv
#   inflating: test_10m_d/Cluster110.csv
#   inflating: test_10m_d/Cluster123.csv
#   inflating: test_10m_d/Cluster393.csv
#   inflating: test_10m_d/Cluster555.csv
#   inflating: test_10m_d/Cluster459.csv
#   inflating: test_10m_d/Cluster829.csv
#   inflating: test_10m_d/Cluster822.csv
#   inflating: test_10m_d/Cluster570.csv
#   inflating: test_10m_d/Cluster768.csv
#   inflating: test_10m_d/Cluster108.csv
#   inflating: test_10m_d/Cluster456.csv
#   inflating: test_10m_d/Cluster542.csv
#   inflating: test_10m_d/Cluster250.csv
#   inflating: test_10m_d/Cluster87.csv
#   inflating: test_10m_d/Cluster991.csv
#   inflating: test_10m_d/Cluster840.csv
#   inflating: test_10m_d/Cluster300.csv
#   inflating: test_10m_d/Cluster11.csv
#   inflating: test_10m_d/Cluster377.csv
#   inflating: test_10m_d/Cluster694.csv
#   inflating: test_10m_d/Cluster223.csv
#   inflating: test_10m_d/Cluster150.csv
#   inflating: test_10m_d/Cluster184.csv
#   inflating: test_10m_d/Cluster34.csv
#   inflating: test_10m_d/Cluster371.csv
#   inflating: test_10m_d/Cluster1007.csv
#   inflating: test_10m_d/Cluster959.csv
#   inflating: test_10m_d/Cluster217.csv
#   inflating: test_10m_d/Cluster863.csv
#   inflating: test_10m_d/Cluster769.csv
#   inflating: test_10m_d/Cluster306.csv
#   inflating: test_10m_d/Cluster195.csv
#   inflating: test_10m_d/Cluster395.csv
#   inflating: test_10m_d/Cluster557.csv
#   inflating: test_10m_d/Cluster524.csv
#   inflating: test_10m_d/Cluster755.csv
#   inflating: test_10m_d/Cluster164.csv
#   inflating: test_10m_d/Cluster844.csv
#   inflating: test_10m_d/Cluster33.csv
#   inflating: test_10m_d/Cluster595.csv
#   inflating: test_10m_d/Cluster292.csv
#   inflating: test_10m_d/Cluster607.csv
#   inflating: test_10m_d/Cluster345.csv
#   inflating: test_10m_d/Cluster478.csv
#   inflating: test_10m_d/Cluster897.csv
#   inflating: test_10m_d/Cluster339.csv
#   inflating: test_10m_d/Cluster151.csv
#   inflating: test_10m_d/Cluster628.csv
#   inflating: test_10m_d/Cluster21.csv
#   inflating: test_10m_d/Cluster736.csv
#   inflating: test_10m_d/Cluster126.csv
#   inflating: test_10m_d/Cluster270.csv
#   inflating: test_10m_d/Cluster210.csv
#   inflating: test_10m_d/Cluster940.csv
#   inflating: test_10m_d/Cluster695.csv
#   inflating: test_10m_d/Cluster545.csv
#   inflating: test_10m_d/Cluster509.csv
#   inflating: test_10m_d/Cluster383.csv
#   inflating: test_10m_d/Cluster258.csv
#   inflating: test_10m_d/Cluster942.csv
#   inflating: test_10m_d/Cluster207.csv
#   inflating: test_10m_d/Cluster146.csv
#   inflating: test_10m_d/Cluster47.csv
#   inflating: test_10m_d/Cluster114.csv
#   inflating: test_10m_d/Cluster760.csv
#   inflating: test_10m_d/Cluster865.csv
#   inflating: test_10m_d/Cluster143.csv
#   inflating: test_10m_d/Cluster418.csv
#   inflating: test_10m_d/output.csv
#   inflating: test_10m_d/Cluster446.csv
#   inflating: test_10m_d/Cluster278.csv
#   inflating: test_10m_d/Cluster497.csv
#   inflating: test_10m_d/Cluster141.csv
#   inflating: test_10m_d/Cluster709.csv
#   inflating: test_10m_d/Cluster782.csv
#   inflating: test_10m_d/Cluster109.csv
#   inflating: test_10m_d/Cluster699.csv
#   inflating: test_10m_d/Cluster436.csv
#   inflating: test_10m_d/Cluster896.csv
#   inflating: test_10m_d/Cluster1011.csv
#   inflating: test_10m_d/Cluster967.csv
#   inflating: test_10m_d/Cluster305.csv
#   inflating: test_10m_d/Cluster323.csv
#   inflating: test_10m_d/Cluster684.csv
#   inflating: test_10m_d/Cluster177.csv
#   inflating: test_10m_d/Cluster1017.csv
#   inflating: test_10m_d/Cluster892.csv
#   inflating: test_10m_d/Cluster602.csv
#   inflating: test_10m_d/Cluster329.csv
#   inflating: test_10m_d/Cluster824.csv
#   inflating: test_10m_d/Cluster90.csv
#   inflating: test_10m_d/Cluster234.csv
#   inflating: test_10m_d/Cluster612.csv
#   inflating: test_10m_d/Cluster861.csv
#   inflating: test_10m_d/Cluster372.csv
#   inflating: test_10m_d/Cluster740.csv
#   inflating: test_10m_d/Cluster647.csv
#   inflating: test_10m_d/Cluster707.csv
#   inflating: test_10m_d/Cluster733.csv
#   inflating: test_10m_d/Cluster584.csv
#   inflating: test_10m_d/Cluster175.csv
#   inflating: test_10m_d/Cluster764.csv
#   inflating: test_10m_d/Cluster620.csv
#   inflating: test_10m_d/Cluster162.csv
#   inflating: test_10m_d/Cluster75.csv
#   inflating: test_10m_d/Cluster122.csv
#   inflating: test_10m_d/Cluster166.csv
#   inflating: test_10m_d/Cluster165.csv
#   inflating: test_10m_d/Cluster835.csv
#   inflating: test_10m_d/Cluster978.csv
#   inflating: test_10m_d/Cluster353.csv
#   inflating: test_10m_d/Cluster1012.csv
#   inflating: test_10m_d/Cluster238.csv
#   inflating: test_10m_d/Cluster728.csv
#   inflating: test_10m_d/Cluster533.csv
#   inflating: test_10m_d/Cluster486.csv
#   inflating: test_10m_d/Cluster635.csv
#   inflating: test_10m_d/Cluster634.csv
#   inflating: test_10m_d/Cluster310.csv
#   inflating: test_10m_d/Cluster643.csv
#   inflating: test_10m_d/Cluster29.csv
#   inflating: test_10m_d/Cluster663.csv
#   inflating: test_10m_d/Cluster618.csv
#   inflating: test_10m_d/Cluster881.csv
#   inflating: test_10m_d/Cluster334.csv
#   inflating: test_10m_d/Cluster173.csv
#   inflating: test_10m_d/Cluster349.csv
#   inflating: test_10m_d/Cluster720.csv
#   inflating: test_10m_d/Cluster144.csv
#   inflating: test_10m_d/Cluster298.csv
#   inflating: test_10m_d/Cluster833.csv
#   inflating: test_10m_d/Cluster938.csv
#   inflating: test_10m_d/Cluster933.csv
#   inflating: test_10m_d/Cluster206.csv
#   inflating: test_10m_d/Cluster692.csv
#   inflating: test_10m_d/Cluster544.csv
#   inflating: test_10m_d/Cluster818.csv
#   inflating: test_10m_d/Cluster301.csv
#   inflating: test_10m_d/Cluster57.csv
#   inflating: test_10m_d/Cluster838.csv
#   inflating: test_10m_d/Cluster686.csv
#   inflating: test_10m_d/Cluster170.csv
#   inflating: test_10m_d/Cluster898.csv
#   inflating: test_10m_d/Cluster112.csv
#   inflating: test_10m_d/Cluster856.csv
#   inflating: test_10m_d/Cluster848.csv
#   inflating: test_10m_d/Cluster527.csv
#   inflating: test_10m_d/Cluster188.csv
#   inflating: test_10m_d/Cluster688.csv
#   inflating: test_10m_d/Cluster212.csv
#   inflating: test_10m_d/Cluster532.csv
#   inflating: test_10m_d/Cluster390.csv
#   inflating: test_10m_d/Cluster724.csv
#   inflating: test_10m_d/Cluster414.csv
#   inflating: test_10m_d/Cluster17.csv
#   inflating: test_10m_d/Cluster642.csv
#   inflating: test_10m_d/Cluster921.csv
#   inflating: test_10m_d/Cluster830.csv
#   inflating: test_10m_d/Cluster803.csv
#   inflating: test_10m_d/Cluster718.csv
#   inflating: test_10m_d/Cluster163.csv
#   inflating: test_10m_d/Cluster993.csv
#   inflating: test_10m_d/Cluster714.csv
#   inflating: test_10m_d/Cluster777.csv
#   inflating: test_10m_d/Cluster254.csv
#   inflating: test_10m_d/Cluster886.csv
#   inflating: test_10m_d/Cluster505.csv
#   inflating: test_10m_d/Cluster444.csv
#   inflating: test_10m_d/Cluster367.csv
#   inflating: test_10m_d/Cluster139.csv
#   inflating: test_10m_d/Cluster914.csv
#   inflating: test_10m_d/Cluster888.csv
#   inflating: test_10m_d/Cluster849.csv
#   inflating: test_10m_d/Cluster779.csv
#   inflating: test_10m_d/Cluster916.csv
#   inflating: test_10m_d/Cluster726.csv
#   inflating: test_10m_d/Cluster955.csv
#   inflating: test_10m_d/Cluster574.csv
#   inflating: test_10m_d/Cluster454.csv
#   inflating: test_10m_d/Cluster763.csv
#   inflating: test_10m_d/Cluster297.csv
#   inflating: test_10m_d/Cluster28.csv
#   inflating: test_10m_d/Cluster14.csv
#   inflating: test_10m_d/Cluster72.csv
#   inflating: test_10m_d/Cluster309.csv
#   inflating: test_10m_d/Cluster264.csv
#   inflating: test_10m_d/Cluster902.csv
#   inflating: test_10m_d/Cluster379.csv
#   inflating: test_10m_d/Cluster408.csv
#   inflating: test_10m_d/Cluster625.csv
#   inflating: test_10m_d/Cluster157.csv
#   inflating: test_10m_d/Cluster219.csv
#   inflating: test_10m_d/Cluster502.csv
#   inflating: test_10m_d/Cluster193.csv
#   inflating: test_10m_d/Cluster423.csv
#   inflating: test_10m_d/Cluster589.csv
#   inflating: test_10m_d/Cluster616.csv
#   inflating: test_10m_d/Cluster559.csv
#   inflating: test_10m_d/Cluster939.csv
#   inflating: test_10m_d/Cluster15.csv
#   inflating: test_10m_d/Cluster496.csv
#   inflating: test_10m_d/Cluster917.csv
#   inflating: test_10m_d/Cluster540.csv
#   inflating: test_10m_d/Cluster93.csv
#   inflating: test_10m_d/Cluster866.csv
#   inflating: test_10m_d/Cluster743.csv
#   inflating: test_10m_d/Cluster273.csv
#   inflating: test_10m_d/Cluster366.csv
#   inflating: test_10m_d/Cluster22.csv
#   inflating: test_10m_d/Cluster677.csv
#   inflating: test_10m_d/Cluster553.csv
#   inflating: test_10m_d/Cluster810.csv
#   inflating: test_10m_d/Cluster701.csv
#   inflating: test_10m_d/Cluster203.csv
#   inflating: test_10m_d/Cluster894.csv
#   inflating: test_10m_d/Cluster265.csv
#   inflating: test_10m_d/Cluster937.csv
#   inflating: test_10m_d/Cluster913.csv
#   inflating: test_10m_d/Cluster351.csv
#   inflating: test_10m_d/Cluster24.csv
#   inflating: test_10m_d/Cluster693.csv
#   inflating: test_10m_d/Cluster482.csv
#   inflating: test_10m_d/Cluster474.csv
#   inflating: test_10m_d/Cluster552.csv
#   inflating: test_10m_d/Cluster324.csv
#   inflating: test_10m_d/Cluster58.csv
#   inflating: test_10m_d/Cluster261.csv
#   inflating: test_10m_d/Cluster409.csv
#   inflating: test_10m_d/Cluster864.csv
#   inflating: test_10m_d/Cluster401.csv
#   inflating: test_10m_d/Cluster489.csv
#   inflating: test_10m_d/Cluster211.csv
#   inflating: test_10m_d/Cluster815.csv
#   inflating: test_10m_d/Cluster614.csv
#   inflating: test_10m_d/Cluster773.csv
#   inflating: test_10m_d/Cluster400.csv
#   inflating: test_10m_d/Cluster919.csv
#   inflating: test_10m_d/Cluster874.csv
#   inflating: test_10m_d/Cluster192.csv
#   inflating: test_10m_d/Cluster197.csv
#   inflating: test_10m_d/Cluster624.csv
#   inflating: test_10m_d/Cluster578.csv
#   inflating: test_10m_d/Cluster132.csv
#   inflating: test_10m_d/Cluster398.csv
#   inflating: test_10m_d/Cluster982.csv
#   inflating: test_10m_d/Cluster382.csv
#   inflating: test_10m_d/Cluster236.csv
#   inflating: test_10m_d/Cluster860.csv
#   inflating: test_10m_d/Cluster771.csv
#   inflating: test_10m_d/Cluster176.csv
#   inflating: test_10m_d/Cluster232.csv
#   inflating: test_10m_d/Cluster479.csv
#   inflating: test_10m_d/Cluster543.csv
#   inflating: test_10m_d/Cluster498.csv
#   inflating: test_10m_d/Cluster800.csv
#   inflating: test_10m_d/Cluster312.csv
#   inflating: test_10m_d/Cluster275.csv
#   inflating: test_10m_d/Cluster925.csv
#   inflating: test_10m_d/Cluster44.csv
#   inflating: test_10m_d/Cluster49.csv
#   inflating: test_10m_d/Cluster365.csv
#   inflating: test_10m_d/Cluster443.csv
#   inflating: test_10m_d/Cluster867.csv
#   inflating: test_10m_d/Cluster798.csv
#   inflating: test_10m_d/Cluster972.csv
#   inflating: test_10m_d/Cluster426.csv
#   inflating: test_10m_d/Cluster428.csv
#   inflating: test_10m_d/Cluster605.csv
#   inflating: test_10m_d/Cluster613.csv
#   inflating: test_10m_d/Cluster851.csv
#   inflating: test_10m_d/Cluster998.csv
#   inflating: test_10m_d/Cluster536.csv
#   inflating: test_10m_d/Cluster875.csv
#   inflating: test_10m_d/Cluster725.csv
#   inflating: test_10m_d/Cluster823.csv
#   inflating: test_10m_d/Cluster229.csv
#   inflating: test_10m_d/Cluster169.csv
#   inflating: test_10m_d/Cluster276.csv
#   inflating: test_10m_d/Cluster778.csv
#   inflating: test_10m_d/Cluster62.csv
#   inflating: test_10m_d/Cluster522.csv
#   inflating: test_10m_d/Cluster762.csv
#   inflating: test_10m_d/Cluster417.csv
#   inflating: test_10m_d/Cluster429.csv
#   inflating: test_10m_d/Cluster587.csv
#   inflating: test_10m_d/Cluster354.csv
#   inflating: test_10m_d/Cluster475.csv
#   inflating: test_10m_d/Cluster208.csv
#   inflating: test_10m_d/Cluster194.csv
#   inflating: test_10m_d/Cluster719.csv
#   inflating: test_10m_d/Cluster1008.csv
#   inflating: test_10m_d/Cluster375.csv
#   inflating: test_10m_d/Cluster549.csv
#   inflating: test_10m_d/Cluster493.csv
#   inflating: test_10m_d/Cluster326.csv
#   inflating: test_10m_d/Cluster525.csv
#   inflating: test_10m_d/Cluster667.csv
#   inflating: test_10m_d/Cluster541.csv
#   inflating: test_10m_d/Cluster149.csv
#   inflating: test_10m_d/Cluster727.csv
#   inflating: test_10m_d/Cluster106.csv
#   inflating: test_10m_d/Cluster330.csv
#   inflating: test_10m_d/Cluster94.csv
#   inflating: test_10m_d/Cluster661.csv
#   inflating: test_10m_d/Cluster322.csv
#   inflating: test_10m_d/Cluster328.csv
#   inflating: test_10m_d/Cluster98.csv
#   inflating: test_10m_d/Cluster656.csv
#   inflating: test_10m_d/Cluster969.csv
#   inflating: test_10m_d/Cluster280.csv
#   inflating: test_10m_d/Cluster397.csv
#   inflating: test_10m_d/Cluster191.csv
#   inflating: test_10m_d/Cluster266.csv
# ...
#   inflating: test_15m_d/Cluster65.csv
#   inflating: test_15m_d/Cluster650.csv
#   inflating: test_15m_d/Cluster651.csv
#   inflating: test_15m_d/Cluster652.csv
#   inflating: test_15m_d/Cluster653.csv
#   inflating: test_15m_d/Cluster654.csv
#   inflating: test_15m_d/Cluster655.csv
#   inflating: test_15m_d/Cluster656.csv
#   inflating: test_15m_d/Cluster657.csv
#   inflating: test_15m_d/Cluster658.csv
#   inflating: test_15m_d/Cluster659.csv
#   inflating: test_15m_d/Cluster66.csv
#   inflating: test_15m_d/Cluster660.csv
#   inflating: test_15m_d/Cluster661.csv
#   inflating: test_15m_d/Cluster662.csv
#   inflating: test_15m_d/Cluster663.csv
#   inflating: test_15m_d/Cluster664.csv
#   inflating: test_15m_d/Cluster665.csv
#   inflating: test_15m_d/Cluster666.csv
#   inflating: test_15m_d/Cluster667.csv
#   inflating: test_15m_d/Cluster668.csv
#   inflating: test_15m_d/Cluster669.csv
#   inflating: test_15m_d/Cluster67.csv
#   inflating: test_15m_d/Cluster670.csv
#   inflating: test_15m_d/Cluster671.csv
#   inflating: test_15m_d/Cluster672.csv
#   inflating: test_15m_d/Cluster673.csv
#   inflating: test_15m_d/Cluster674.csv
#   inflating: test_15m_d/Cluster675.csv
#   inflating: test_15m_d/Cluster676.csv
#   inflating: test_15m_d/Cluster677.csv
#   inflating: test_15m_d/Cluster678.csv
#   inflating: test_15m_d/Cluster679.csv
#   inflating: test_15m_d/Cluster68.csv
#   inflating: test_15m_d/Cluster680.csv
#   inflating: test_15m_d/Cluster681.csv
#   inflating: test_15m_d/Cluster682.csv
#   inflating: test_15m_d/Cluster683.csv
#   inflating: test_15m_d/Cluster684.csv
#   inflating: test_15m_d/Cluster685.csv
#   inflating: test_15m_d/Cluster686.csv
#   inflating: test_15m_d/Cluster687.csv
#   inflating: test_15m_d/Cluster688.csv
#   inflating: test_15m_d/Cluster689.csv
#   inflating: test_15m_d/Cluster69.csv
#   inflating: test_15m_d/Cluster690.csv
#   inflating: test_15m_d/Cluster691.csv
#   inflating: test_15m_d/Cluster692.csv
#   inflating: test_15m_d/Cluster693.csv
#   inflating: test_15m_d/Cluster694.csv
#   inflating: test_15m_d/Cluster695.csv
#   inflating: test_15m_d/Cluster696.csv
#   inflating: test_15m_d/Cluster697.csv
#   inflating: test_15m_d/Cluster698.csv
#   inflating: test_15m_d/Cluster699.csv
#   inflating: test_15m_d/Cluster7.csv
#   inflating: test_15m_d/Cluster70.csv
#   inflating: test_15m_d/Cluster700.csv
#   inflating: test_15m_d/Cluster701.csv
#   inflating: test_15m_d/Cluster702.csv
#   inflating: test_15m_d/Cluster703.csv
#   inflating: test_15m_d/Cluster704.csv
#   inflating: test_15m_d/Cluster705.csv
#   inflating: test_15m_d/Cluster706.csv
#   inflating: test_15m_d/Cluster707.csv
#   inflating: test_15m_d/Cluster708.csv
#   inflating: test_15m_d/Cluster709.csv
#   inflating: test_15m_d/Cluster71.csv
#   inflating: test_15m_d/Cluster710.csv
#   inflating: test_15m_d/Cluster711.csv
#   inflating: test_15m_d/Cluster712.csv
#   inflating: test_15m_d/Cluster713.csv
#   inflating: test_15m_d/Cluster714.csv
#   inflating: test_15m_d/Cluster715.csv
#   inflating: test_15m_d/Cluster716.csv
#   inflating: test_15m_d/Cluster717.csv
#   inflating: test_15m_d/Cluster718.csv
#   inflating: test_15m_d/Cluster719.csv
#   inflating: test_15m_d/Cluster72.csv
#   inflating: test_15m_d/Cluster720.csv
#   inflating: test_15m_d/Cluster721.csv
#   inflating: test_15m_d/Cluster722.csv
#   inflating: test_15m_d/Cluster723.csv
#   inflating: test_15m_d/Cluster724.csv
#   inflating: test_15m_d/Cluster725.csv
#   inflating: test_15m_d/Cluster726.csv
#   inflating: test_15m_d/Cluster727.csv
#   inflating: test_15m_d/Cluster728.csv
#   inflating: test_15m_d/Cluster729.csv
#   inflating: test_15m_d/Cluster73.csv
#   inflating: test_15m_d/Cluster730.csv
#   inflating: test_15m_d/Cluster731.csv
#   inflating: test_15m_d/Cluster732.csv
#   inflating: test_15m_d/Cluster733.csv
#   inflating: test_15m_d/Cluster734.csv
#   inflating: test_15m_d/Cluster735.csv
#   inflating: test_15m_d/Cluster736.csv
#   inflating: test_15m_d/Cluster737.csv
#   inflating: test_15m_d/Cluster738.csv
#   inflating: test_15m_d/Cluster739.csv
#   inflating: test_15m_d/Cluster74.csv
#   inflating: test_15m_d/Cluster740.csv
#   inflating: test_15m_d/Cluster741.csv
#   inflating: test_15m_d/Cluster742.csv
#   inflating: test_15m_d/Cluster743.csv
#   inflating: test_15m_d/Cluster744.csv
#   inflating: test_15m_d/Cluster745.csv
#   inflating: test_15m_d/Cluster746.csv
#   inflating: test_15m_d/Cluster747.csv
#   inflating: test_15m_d/Cluster748.csv
#   inflating: test_15m_d/Cluster749.csv
#   inflating: test_15m_d/Cluster75.csv
#   inflating: test_15m_d/Cluster750.csv
#   inflating: test_15m_d/Cluster751.csv
#   inflating: test_15m_d/Cluster752.csv
#   inflating: test_15m_d/Cluster753.csv
#   inflating: test_15m_d/Cluster754.csv
#   inflating: test_15m_d/Cluster755.csv
#   inflating: test_15m_d/Cluster756.csv
#   inflating: test_15m_d/Cluster757.csv
#   inflating: test_15m_d/Cluster758.csv
#   inflating: test_15m_d/Cluster759.csv
#   inflating: test_15m_d/Cluster76.csv
#   inflating: test_15m_d/Cluster760.csv
#   inflating: test_15m_d/Cluster761.csv
#   inflating: test_15m_d/Cluster762.csv
#   inflating: test_15m_d/Cluster763.csv
#   inflating: test_15m_d/Cluster764.csv
#   inflating: test_15m_d/Cluster765.csv
#   inflating: test_15m_d/Cluster766.csv
#   inflating: test_15m_d/Cluster767.csv
#   inflating: test_15m_d/Cluster768.csv
#   inflating: test_15m_d/Cluster769.csv
#   inflating: test_15m_d/Cluster77.csv
#   inflating: test_15m_d/Cluster770.csv
#   inflating: test_15m_d/Cluster771.csv
#   inflating: test_15m_d/Cluster772.csv
#   inflating: test_15m_d/Cluster773.csv
#   inflating: test_15m_d/Cluster774.csv
#   inflating: test_15m_d/Cluster775.csv
#   inflating: test_15m_d/Cluster776.csv
#   inflating: test_15m_d/Cluster777.csv
#   inflating: test_15m_d/Cluster778.csv
#   inflating: test_15m_d/Cluster779.csv
#   inflating: test_15m_d/Cluster78.csv
#   inflating: test_15m_d/Cluster780.csv
#   inflating: test_15m_d/Cluster781.csv
#   inflating: test_15m_d/Cluster782.csv
#   inflating: test_15m_d/Cluster783.csv
#   inflating: test_15m_d/Cluster784.csv
#   inflating: test_15m_d/Cluster785.csv
#   inflating: test_15m_d/Cluster786.csv
#   inflating: test_15m_d/Cluster787.csv
#   inflating: test_15m_d/Cluster788.csv
#   inflating: test_15m_d/Cluster789.csv
#   inflating: test_15m_d/Cluster79.csv
#   inflating: test_15m_d/Cluster790.csv
#   inflating: test_15m_d/Cluster791.csv
#   inflating: test_15m_d/Cluster792.csv
#   inflating: test_15m_d/Cluster793.csv
#   inflating: test_15m_d/Cluster794.csv
#   inflating: test_15m_d/Cluster795.csv
#   inflating: test_15m_d/Cluster796.csv
#   inflating: test_15m_d/Cluster797.csv
#   inflating: test_15m_d/Cluster798.csv
#   inflating: test_15m_d/Cluster799.csv
#   inflating: test_15m_d/Cluster8.csv
#   inflating: test_15m_d/Cluster80.csv
#   inflating: test_15m_d/Cluster800.csv
#   inflating: test_15m_d/Cluster801.csv
#   inflating: test_15m_d/Cluster802.csv
#   inflating: test_15m_d/Cluster803.csv
#   inflating: test_15m_d/Cluster804.csv
#   inflating: test_15m_d/Cluster805.csv
#   inflating: test_15m_d/Cluster806.csv
#   inflating: test_15m_d/Cluster807.csv
#   inflating: test_15m_d/Cluster808.csv
#   inflating: test_15m_d/Cluster809.csv
#   inflating: test_15m_d/Cluster81.csv
#   inflating: test_15m_d/Cluster810.csv
#   inflating: test_15m_d/Cluster811.csv
#   inflating: test_15m_d/Cluster812.csv
#   inflating: test_15m_d/Cluster813.csv
#   inflating: test_15m_d/Cluster814.csv
#   inflating: test_15m_d/Cluster815.csv
#   inflating: test_15m_d/Cluster816.csv
#   inflating: test_15m_d/Cluster817.csv
#   inflating: test_15m_d/Cluster818.csv
#   inflating: test_15m_d/Cluster819.csv
#   inflating: test_15m_d/Cluster82.csv
#   inflating: test_15m_d/Cluster820.csv
#   inflating: test_15m_d/Cluster821.csv
#   inflating: test_15m_d/Cluster822.csv
#   inflating: test_15m_d/Cluster823.csv
#   inflating: test_15m_d/Cluster824.csv
#   inflating: test_15m_d/Cluster825.csv
#   inflating: test_15m_d/Cluster826.csv
#   inflating: test_15m_d/Cluster827.csv
#   inflating: test_15m_d/Cluster828.csv
#   inflating: test_15m_d/Cluster829.csv
#   inflating: test_15m_d/Cluster83.csv
#   inflating: test_15m_d/Cluster830.csv
#   inflating: test_15m_d/Cluster831.csv
#   inflating: test_15m_d/Cluster832.csv
#   inflating: test_15m_d/Cluster833.csv
#   inflating: test_15m_d/Cluster834.csv
#   inflating: test_15m_d/Cluster835.csv
#   inflating: test_15m_d/Cluster836.csv
#   inflating: test_15m_d/Cluster837.csv
#   inflating: test_15m_d/Cluster838.csv
#   inflating: test_15m_d/Cluster839.csv
#   inflating: test_15m_d/Cluster84.csv
#   inflating: test_15m_d/Cluster840.csv
#   inflating: test_15m_d/Cluster841.csv
#   inflating: test_15m_d/Cluster842.csv
#   inflating: test_15m_d/Cluster843.csv
#   inflating: test_15m_d/Cluster844.csv
#   inflating: test_15m_d/Cluster845.csv
#   inflating: test_15m_d/Cluster846.csv
#   inflating: test_15m_d/Cluster847.csv
#   inflating: test_15m_d/Cluster848.csv
#   inflating: test_15m_d/Cluster849.csv
#   inflating: test_15m_d/Cluster85.csv
#   inflating: test_15m_d/Cluster850.csv
#   inflating: test_15m_d/Cluster851.csv
#   inflating: test_15m_d/Cluster852.csv
#   inflating: test_15m_d/Cluster853.csv
#   inflating: test_15m_d/Cluster854.csv
#   inflating: test_15m_d/Cluster855.csv
#   inflating: test_15m_d/Cluster856.csv
#   inflating: test_15m_d/Cluster857.csv
#   inflating: test_15m_d/Cluster858.csv
#   inflating: test_15m_d/Cluster859.csv
#   inflating: test_15m_d/Cluster86.csv
#   inflating: test_15m_d/Cluster860.csv
#   inflating: test_15m_d/Cluster861.csv
#   inflating: test_15m_d/Cluster862.csv
#   inflating: test_15m_d/Cluster863.csv
#   inflating: test_15m_d/Cluster864.csv
#   inflating: test_15m_d/Cluster865.csv
#   inflating: test_15m_d/Cluster866.csv
#   inflating: test_15m_d/Cluster867.csv
#   inflating: test_15m_d/Cluster868.csv
#   inflating: test_15m_d/Cluster869.csv
#   inflating: test_15m_d/Cluster87.csv
#   inflating: test_15m_d/Cluster870.csv
#   inflating: test_15m_d/Cluster871.csv
#   inflating: test_15m_d/Cluster872.csv
#   inflating: test_15m_d/Cluster873.csv
#   inflating: test_15m_d/Cluster874.csv
#   inflating: test_15m_d/Cluster875.csv
#   inflating: test_15m_d/Cluster876.csv
#   inflating: test_15m_d/Cluster877.csv
#   inflating: test_15m_d/Cluster878.csv
#   inflating: test_15m_d/Cluster879.csv
#   inflating: test_15m_d/Cluster88.csv
#   inflating: test_15m_d/Cluster880.csv
#   inflating: test_15m_d/Cluster881.csv
#   inflating: test_15m_d/Cluster882.csv
#   inflating: test_15m_d/Cluster883.csv
#   inflating: test_15m_d/Cluster884.csv
#   inflating: test_15m_d/Cluster885.csv
#   inflating: test_15m_d/Cluster886.csv
#   inflating: test_15m_d/Cluster887.csv
#   inflating: test_15m_d/Cluster888.csv
#   inflating: test_15m_d/Cluster889.csv
#   inflating: test_15m_d/Cluster89.csv
#   inflating: test_15m_d/Cluster890.csv
#   inflating: test_15m_d/Cluster891.csv
#   inflating: test_15m_d/Cluster892.csv
#   inflating: test_15m_d/Cluster893.csv
#   inflating: test_15m_d/Cluster894.csv
#   inflating: test_15m_d/Cluster895.csv
#   inflating: test_15m_d/Cluster896.csv
#   inflating: test_15m_d/Cluster897.csv
#   inflating: test_15m_d/Cluster898.csv
#   inflating: test_15m_d/Cluster899.csv
#   inflating: test_15m_d/Cluster9.csv
#   inflating: test_15m_d/Cluster90.csv
#   inflating: test_15m_d/Cluster900.csv
#   inflating: test_15m_d/Cluster901.csv
#   inflating: test_15m_d/Cluster902.csv
#   inflating: test_15m_d/Cluster903.csv
#   inflating: test_15m_d/Cluster904.csv
#   inflating: test_15m_d/Cluster905.csv
#   inflating: test_15m_d/Cluster906.csv
#   inflating: test_15m_d/Cluster907.csv
#   inflating: test_15m_d/Cluster908.csv
#   inflating: test_15m_d/Cluster909.csv
#   inflating: test_15m_d/Cluster91.csv
#   inflating: test_15m_d/Cluster910.csv
#   inflating: test_15m_d/Cluster911.csv
#   inflating: test_15m_d/Cluster912.csv
#   inflating: test_15m_d/Cluster913.csv
#   inflating: test_15m_d/Cluster914.csv
#   inflating: test_15m_d/Cluster915.csv
#   inflating: test_15m_d/Cluster916.csv
#   inflating: test_15m_d/Cluster917.csv
#   inflating: test_15m_d/Cluster918.csv
#   inflating: test_15m_d/Cluster919.csv
#   inflating: test_15m_d/Cluster92.csv
#   inflating: test_15m_d/Cluster920.csv
#   inflating: test_15m_d/Cluster921.csv
#   inflating: test_15m_d/Cluster922.csv
#   inflating: test_15m_d/Cluster923.csv
#   inflating: test_15m_d/Cluster924.csv
#   inflating: test_15m_d/Cluster925.csv
#   inflating: test_15m_d/Cluster926.csv
#   inflating: test_15m_d/Cluster927.csv
#   inflating: test_15m_d/Cluster928.csv
#   inflating: test_15m_d/Cluster929.csv
#   inflating: test_15m_d/Cluster93.csv
#   inflating: test_15m_d/Cluster930.csv
#   inflating: test_15m_d/Cluster931.csv
#   inflating: test_15m_d/Cluster932.csv
#   inflating: test_15m_d/Cluster933.csv
#   inflating: test_15m_d/Cluster934.csv
#   inflating: test_15m_d/Cluster935.csv
#   inflating: test_15m_d/Cluster936.csv
#   inflating: test_15m_d/Cluster937.csv
#   inflating: test_15m_d/Cluster938.csv
#   inflating: test_15m_d/Cluster939.csv
#   inflating: test_15m_d/Cluster94.csv
#   inflating: test_15m_d/Cluster940.csv
#   inflating: test_15m_d/Cluster941.csv
#   inflating: test_15m_d/Cluster942.csv
#   inflating: test_15m_d/Cluster943.csv
#   inflating: test_15m_d/Cluster944.csv
#   inflating: test_15m_d/Cluster945.csv
#   inflating: test_15m_d/Cluster946.csv
#   inflating: test_15m_d/Cluster947.csv
#   inflating: test_15m_d/Cluster948.csv
#   inflating: test_15m_d/Cluster949.csv
#   inflating: test_15m_d/Cluster95.csv
#   inflating: test_15m_d/Cluster950.csv
#   inflating: test_15m_d/Cluster951.csv
#   inflating: test_15m_d/Cluster952.csv
#   inflating: test_15m_d/Cluster953.csv
#   inflating: test_15m_d/Cluster954.csv
#   inflating: test_15m_d/Cluster955.csv
#   inflating: test_15m_d/Cluster956.csv
#   inflating: test_15m_d/Cluster957.csv
#   inflating: test_15m_d/Cluster958.csv
#   inflating: test_15m_d/Cluster959.csv
#   inflating: test_15m_d/Cluster96.csv
#   inflating: test_15m_d/Cluster960.csv
#   inflating: test_15m_d/Cluster961.csv
#   inflating: test_15m_d/Cluster962.csv
#   inflating: test_15m_d/Cluster963.csv
#   inflating: test_15m_d/Cluster964.csv
#   inflating: test_15m_d/Cluster965.csv
#   inflating: test_15m_d/Cluster966.csv
#   inflating: test_15m_d/Cluster967.csv
#   inflating: test_15m_d/Cluster968.csv
#   inflating: test_15m_d/Cluster969.csv
#   inflating: test_15m_d/Cluster97.csv
#   inflating: test_15m_d/Cluster970.csv
#   inflating: test_15m_d/Cluster971.csv
#   inflating: test_15m_d/Cluster972.csv
#   inflating: test_15m_d/Cluster973.csv
#   inflating: test_15m_d/Cluster974.csv
#   inflating: test_15m_d/Cluster975.csv
#   inflating: test_15m_d/Cluster976.csv
#   inflating: test_15m_d/Cluster977.csv
#   inflating: test_15m_d/Cluster978.csv
#   inflating: test_15m_d/Cluster979.csv
#   inflating: test_15m_d/Cluster98.csv
#   inflating: test_15m_d/Cluster980.csv
#   inflating: test_15m_d/Cluster981.csv
#   inflating: test_15m_d/Cluster982.csv
#   inflating: test_15m_d/Cluster983.csv
#   inflating: test_15m_d/Cluster984.csv
#   inflating: test_15m_d/Cluster985.csv
#   inflating: test_15m_d/Cluster986.csv
#   inflating: test_15m_d/Cluster987.csv
#   inflating: test_15m_d/Cluster988.csv
#   inflating: test_15m_d/Cluster989.csv
#   inflating: test_15m_d/Cluster99.csv
#   inflating: test_15m_d/Cluster990.csv
#   inflating: test_15m_d/Cluster991.csv
#   inflating: test_15m_d/Cluster992.csv
#   inflating: test_15m_d/Cluster993.csv
#   inflating: test_15m_d/Cluster994.csv
#   inflating: test_15m_d/Cluster995.csv
#   inflating: test_15m_d/Cluster996.csv
#   inflating: test_15m_d/Cluster997.csv
#   inflating: test_15m_d/Cluster998.csv
#   inflating: test_15m_d/Cluster999.csv
#   inflating: test_15m_d/output.csv
# Archive:  saved_db_20m.zip
#   inflating: saved_db_20m.csv

# %% [markdown]
# These are the functions for running and reporting

# %%
import numpy as np
from vec_db import VecDB
import time
from dataclasses import dataclass
from typing import List
from memory_profiler import memory_usage
import gc

@dataclass
class Result:
    run_time: float
    top_k: int
    db_ids: List[int]
    actual_ids: List[int]

results = []
to_print_arr = []

def run_queries(db, query, top_k, actual_ids, num_runs):
    global results
    results = []
    for _ in range(num_runs):
        tic = time.time()
        db_ids = db.retrive(query, top_k)
        toc = time.time()
        run_time = toc - tic
        results.append(Result(run_time, top_k, db_ids, actual_ids))
    return results

def memory_usage_run_queries(args):
    global results
    # This part is added to calcauate the RAM usage
    mem_before = max(memory_usage())
    mem = memory_usage(proc=(run_queries, args, {}), interval = 1e-3)
    return results, max(mem) - mem_before

def evaluate_result(results: List[Result]):
    # scores are negative. So getting 0 is the best score.
    scores = []
    run_time = []
    for res in results:
        run_time.append(res.run_time)
        # case for retireving number not equal to top_k, socre will be the lowest
        if len(set(res.db_ids)) != res.top_k or len(res.db_ids) != res.top_k:
            scores.append( -1 * len(res.actual_ids) * res.top_k)
            continue
        score = 0
        for id in res.db_ids:
            try:
                ind = res.actual_ids.index(id)
                if ind > res.top_k * 3:
                    score -= ind
            except:
                score -= len(res.actual_ids)
        scores.append(score)

    return sum(scores) / len(scores), sum(run_time) / len(run_time)

def get_actual_ids_first_k(actual_sorted_ids, k):
    return [id for id in actual_sorted_ids if id < k]

# %% [markdown]
# This to generate 10K database and the query using the seed numbers that will be changed at submissions day

# %%
rng = np.random.default_rng(DB_SEED_NUMBER)
vectors = rng.random((10**4, 70), dtype=np.float32)

rng = np.random.default_rng(QUERY_SEED_NUMBER)
query = rng.random((1, 70), dtype=np.float32)

actual_sorted_ids_10k = np.argsort(vectors.dot(query.T).T / (np.linalg.norm(vectors, axis=1) * np.linalg.norm(query)), axis= 1).squeeze().tolist()[::-1]

# %% [markdown]
# Open new DB add 10K then retrieve and evaluate. Then add another 90K (total 100K) then retrieve and evaluate.

# %%
db = VecDB()

records_dict = [{"id": i, "embed": list(row)} for i, row in enumerate(vectors)]
db.insert_records(records_dict)
res = run_queries(db, query, 5, actual_sorted_ids_10k, 1) # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_sorted_ids_10k, 5)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"10K\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)
# Out:
# records size =  10000
# 10000
# 0
# node array size ,  0
# records inserted and serilized successfully
# 10K	score	0.0	time	1.14	RAM	14.93 MB

# %% [markdown]
# Remove exsiting varaibles to empty some RAM

# %%
del vectors
del query
del actual_sorted_ids_10k
del records_dict
del db
gc.collect()
# Out:
# 0

# %% [markdown]
# This code to generate 20M database. The seed (50) will not be changed. Create the same DB and prepare it's files indexes and every related file. <br>
# Note at the submission I'll not run the insert records. <br>
# The query istelf will be changed at submissions day but not the DB

# %%
rng = np.random.default_rng(50)
vectors = rng.random((10**7*2, 70), dtype=np.float32)

rng = np.random.default_rng(QUERY_SEED_NUMBER)
query = rng.random((1, 70), dtype=np.float32)

actual_sorted_ids_20m = np.argsort(vectors.dot(query.T).T / (np.linalg.norm(vectors, axis=1) * np.linalg.norm(query)), axis= 1).squeeze().tolist()[::-1]

# %%
print("Team Number", TEAM_NUMBER)
print("\n".join(to_print_arr))

db = VecDB(file_path = PATH_DB_100K, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**5)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"100K\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)


db = VecDB(file_path = PATH_DB_1M, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**6)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"1M\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)


db = VecDB(file_path = PATH_DB_5M, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**6*5)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"5M\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)


db = VecDB(file_path = PATH_DB_10M, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**6*10)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"10M\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)


db = VecDB(file_path = PATH_DB_15M, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**6*15)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"15M\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)


db = VecDB(file_path = PATH_DB_20M, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**6*20)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"20M\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)
# Out:
# Team Number 1
# 10K	score	0.0	time	1.14	RAM	14.93 MB
# 100K	score	0.0	time	10.66	RAM	14.13 MB
# 1M	score	0.0	time	49.63	RAM	10.12 MB
# 5M	score	-40.0	time	89.58	RAM	1.14 MB
# 10M	score	-46.0	time	115.05	RAM	0.00 MB
# 15M	score	-123.0	time	103.72	RAM	-73.60 MB
# 20M	score	-163.0	time	106.17	RAM	-107.78 MB

# %%
print("Team Number", TEAM_NUMBER)
print("\n".join(to_print_arr))
# Out:
# Team Number 1
# 10K	score	0.0	time	1.14	RAM	14.93 MB
# 100K	score	0.0	time	10.66	RAM	14.13 MB
# 1M	score	0.0	time	49.63	RAM	10.12 MB
# 5M	score	-40.0	time	89.58	RAM	1.14 MB
# 10M	score	-46.0	time	115.05	RAM	0.00 MB
# 15M	score	-123.0	time	103.72	RAM	-73.60 MB
# 20M	score	-163.0	time	106.17	RAM	-107.78 MB

# %%
# Out:
# Mounted at /content/drive
